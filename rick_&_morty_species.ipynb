# %%
import pandas as pd

# %%
Characters = pd.read_csv('R_M_characters.csv')
display(Characters)
# Out:
#                                  name  \
# 0                        Rick Sanchez
# 1                         Morty Smith
# 2                        Summer Smith
# 3                   Jerry Smith Prime
# 4                      Mr. Goldenfold
# ..                                ...
# 606                      Night Summer
# 607                        Rhett Caan
# 608  Jessica (Cronenberged Dimension)
# 609                    Mr. Stringbean
# 610                        Pissmaster
#
#                                                species
# 0                                       Human (Cyborg)
# 1                                                Human
# 2                                                Human
# 3                                                Human
# 4                                                Human
# ..                                                 ...
# 606                                              Human
# 607                                   Omniversal Being
# ...

# %%
pd.set_option('display.max_rows', None)
Characters.loc[Characters['species'].str.contains('alien'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Alien'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Cat'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('cat'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('clone'), 'species'] = 'Clone'
Characters.loc[Characters['species'].str.contains('Clone'), 'species'] = 'Clone'
Characters.loc[Characters['species'].str.contains('Gromflomite'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Human'), 'species'] = 'Human'
Characters.loc[Characters['species'].str.contains('human'), 'species'] = 'Human'
Characters.loc[Characters['species'].str.contains('Unknown'), 'species'] = 'Unknown'
Characters.loc[Characters['species'].str.contains('Larv'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Gear'), 'species'] = 'Gear Person'
Characters.loc[Characters['species'].str.contains('Mr. Poopybutthole'), 'species'] = 'Mr. Poopybutthole\'s species'
Characters.loc[Characters['species'].str.contains('Robot'), 'species'] = 'Robot'
Characters.loc[Characters['species'].str.contains('Abadongian'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Alphabetrian'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Cromulon'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Cronenberg'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Cronenberg'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Crows'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('Dog'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('Drumbloxian'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Zombodian'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Zigerion'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('unknown'), 'species'] = 'Unknown'
Characters.loc[Characters['species'].str.contains('Ga'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('ian'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('droid'), 'species'] = 'Droid'
Characters.loc[Characters['species'].str.contains('CHUD'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Girl'), 'species'] = 'Human'
Characters.loc[Characters['species'].str.contains('Anthropomorphic Tiger'), 'species'] = 'Human-Animal'
Characters.loc[Characters['species'].str.contains('Bird Person'), 'species'] = 'Human-Animal'
Characters.loc[Characters['species'].str.contains('Centaur'), 'species'] = 'Human-Animal'
Characters.loc[Characters['species'].str.contains('Fish-per'), 'species'] = 'Human-Animal'
Characters.loc[Characters['species'].str.contains('Lizard'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('Amoeba'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Bread'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Collapsing Star'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Computer program'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Cybernetic Space Horro'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Cyclops'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Demon'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Divine Entity'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Dragon'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Zeus'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Dummy'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Elemental construct'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Wasp'), 'species'] = 'Human-Animal'
Characters.loc[Characters['species'].str.contains('Vampire'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Zeus'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Trunk'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Trans'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Tortoise'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('F'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Greek God'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Hivemind'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Hole'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Intelligent hamsters'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('Interdimensional gaseous being'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Jelly'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Mees'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Kor'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Kroo'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Lepr'), 'species'] = 'Human-Animal'
Characters.loc[Characters['species'].str.contains('Living'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Mo'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Mu'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('My'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Oc'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Om'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Pic'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('P'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Rick'), 'species'] = 'Human'
Characters.loc[Characters['species'].str.contains('Rat'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('Person'), 'species'] = 'Human'
Characters.loc[Characters['species'].str.contains('Teddy'), 'species'] = 'Human-Animal'
Characters.loc[Characters['species'].str.contains('Sc'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Sea'), 'species'] = 'Mythological'
Characters.loc[Characters['species'].str.contains('Sent'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Serp'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('Sh'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('Sn'), 'species'] = 'Animal'
Characters.loc[Characters['species'].str.contains('Sp'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Squa'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Squi'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('Sw'), 'species'] = 'Other'
Characters.loc[Characters['species'].str.contains('S'), 'species'] = 'Alien'
Characters.loc[Characters['species'].str.contains('Tiny'), 'species'] = 'Other'

Characters.groupby(['species']).count()
# Out:
#               name
# species
# Alien          170
# Animal          19
# Clone            5
# Droid            3
# Human          336
# Human-Animal    12
# Mythological    19
# Other           26
# Robot           13
# Unknown          8

# %%
Characters.to_csv('R_M_species.csv', index=False)
